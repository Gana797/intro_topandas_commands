# %% [markdown]
# <a href="https://colab.research.google.com/github/Gana797/intro_topandas_commands/blob/main/pandas_basic_commands_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')
#to store in a variable and read file

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()
#display first 5 records
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
#display last 5 records
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.columns
#name of columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
#to show rows and columns
# Out:
# (78, 6)

# %%
df.dtypes
#to display data types
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
pd.set_option('display.max_rows',None)
#to make pandas set option to display all rows data

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.isnull()
#to check null values in all records
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
df.isnull().sum()
#to check null values simply
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.describe(include='all')
#to get summary of all columns and it's values
# Out:
#         rank discipline        phd    service   sex         salary
# count     78         78  78.000000  78.000000    78      78.000000
# unique     3          2        NaN        NaN     2            NaN
# top     Prof          B        NaN        NaN  Male            NaN
# freq      46         42        NaN        NaN    39            NaN
# mean     NaN        NaN  19.705128  15.051282   NaN  108023.782051
# std      NaN        NaN  12.498425  12.139768   NaN   28293.661022
# min      NaN        NaN   1.000000   0.000000   NaN   57800.000000
# 25%      NaN        NaN  10.250000   5.250000   NaN   88612.500000
# 50%      NaN        NaN  18.500000  14.500000   NaN  104671.000000
# 75%      NaN        NaN  27.750000  20.750000   NaN  126774.750000
# max      NaN        NaN  56.000000  51.000000   NaN  186960.000000

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df['phd'].mean()
#to find mean of specific column
# Out:
# 19.705128205128204

# %%
df['phd'].median()
# Out:
# 18.5

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df[['phd','salary']].mean()
#to find mean of more than one column at a time
# Out:
# phd           19.705128
# salary    108023.782051
# dtype: float64

# %%
df['phd'].var()
#variance
# Out:
# 156.21062271062277

# %%
df['salary'].std()
#standard deviation
# Out:
# 28293.661022264165

# %%
df['salary'].skew()
#skewness
# Out:
# 0.45210256755588096

# %%
df['service'].kurt()
#kurtosis
# Out:
# 0.6089806934661852

# %%
df['salary'].count()
# Out:
# 78

# %%
df['rank'].value_counts()
#how many observations in a specific column
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df['salary'].value_counts()
#to count non numeric counts
# Out:
# salary
# 92000     3
# 77500     2
# 72500     2
# 91000     2
# 62884     1
# 73500     1
# 105000    1
# 127512    1
# 97032     1
# 122960    1
# 186960    1
# 103613    1
# 74692     1
# 140096    1
# 151768    1
# 77000     1
# 80225     1
# 74830     1
# 137000    1
# 111512    1
# 144651    1
# 103994    1
# 103750    1
# 109650    1
# 73300     1
# 117555    1
# 63100     1
# 90450     1
# 116450    1
# 78500     1
# 71065     1
# 161101    1
# 105450    1
# 104542    1
# 124312    1
# 109954    1
# 129000    1
# 102000    1
# 93000     1
# 57800     1
# 150480    1
# 153750    1
# 162200    1
# 88000     1
# 134778    1
# 128250    1
# 94350     1
# 107300    1
# 126300    1
# 81285     1
# 122400    1
# 104800    1
# 131205    1
# 110515    1
# 75044     1
# 150500    1
# 146856    1
# 123683    1
# 126933    1
# 119800    1
# 120000    1
# 103275    1
# 155750    1
# 107008    1
# 91300     1
# 103106    1
# 155865    1
# 148750    1
# 99418     1
# 91100     1
# ...

# %%
# prompt: can u import basic library pandas in this notebook

import pandas as pd

# %%
df.iloc[:10,:5]
#index location
# Out:
#         rank discipline  phd  service   sex
# 0       Prof          B   56       49  Male
# 1       Prof          A   12        6  Male
# 2       Prof          A   23       20  Male
# 3       Prof          A   40       31  Male
# 4       Prof          B   20       18  Male
# 5       Prof          A   20       20  Male
# 6  AssocProf          A   20       17  Male
# 7       Prof          A   18       18  Male
# 8       Prof          A   29       19  Male
# 9       Prof          A   51       51  Male

# %%
# prompt: read this file/content/Salaries.csv

import pandas as pd

# Assuming Salaries.csv is in the current working directory or provide the full path
try:
  df = pd.read_csv('/content/Salaries.csv') # Or replace with the correct path
  print(df.head()) # Display the first 5 rows
except FileNotFoundError:
  print("Error: 'Salaries.csv' not found. Please ensure the file exists and the path is correct.")

# %%
# prompt: select first 10 records and first 5 columns

df.iloc[:10, :5]
# Out:
#         rank discipline  phd  service   sex
# 0       Prof          B   56       49  Male
# 1       Prof          A   12        6  Male
# 2       Prof          A   23       20  Male
# 3       Prof          A   40       31  Male
# 4       Prof          B   20       18  Male
# 5       Prof          A   20       20  Male
# 6  AssocProf          A   20       17  Male
# 7       Prof          A   18       18  Male
# 8       Prof          A   29       19  Male
# 9       Prof          A   51       51  Male

# %%
df.groupby('rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
df.groupby('rank')['salary'].mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         123624.804348
# Name: salary, dtype: float64
